# %% [markdown]
# Executive Summary

# %% [markdown]
# I found that UVA has more foreign donors than the average institution, however, UVA receives far less foreign money than many institutions. UVA has 1.88 times as many donors as the average institution, receives 1.10 times as many gifts than the average institution, but UVA receives 57 percent less than the average institution. Each donor gives about $383,000 which is well below UNC who raises almost twice as much in foreign donations from fewer donors. UVA’s problem lies in the size and repeat rate of each relationship and not in the number of relationships UVA has.I would recommend that UVA strengthen their relationships with previous top donors rather than pursuing new relationships.

# %% [markdown]
# Results of Initial Analysis

# %% [markdown]
# Through the initial analysis I was able to determine what kind of money is actually coming from foreign countries. The majority of gifts received by institutions are contracts. In the dataset there are 17,274 contracts which make up about 65% of foreign dollars. Monetary gifts are 10,936 records and make up roughly 35% of foreign dollars. Finally, real estate is only 11 records.
#
# I was also able to visualize the shape of the market. Qatar leads in the total amount of money given with $2.17 billion. England leads in the total number of gifts given. Qatar donates fewer times but much larger donations, while England donated in more instances but moderate donations. Carnegie Mellon leads the institutions in the amount received while receiving $1.48 billion. UCLA leads in the number of gifts received as they have received 3,916 gifts. The mean value that each university receives is $52.5 million while the median of what each university receives is $6.5 million. The large difference between the mean and the median exists because many institutions receive small to medium donations while a few institutions receive huge donations. THis can be seen in the histogram where many institutions have tiny lines connecting them to a country while institutions such as Cornell University and Carnegie Mellon have huge tails connecting them to a country. The histogram also shows that The Qatar Foundation is the largest gift at roughly $2.34 billion in donations. Additionally around 29% of dollars come from undisclosed donors.
#
# In all of this UVA sits as $22.2 million received, 98 gifts received, and 58 donors. Compared against the mean UVA is at 0.43x dollars, 1.10x gifts, and 1.88x donors. Compared against the median of $6.5 million, UVA is 3.4x above average receiving roughly $383,000 per donor. UVA receives considerably less than UT Austin who received $85.9 million and UNC who received $41.3 million. However, UVA’s mean gift of $226,421 does beat UNC’s $144,380. UVA does close large gifts competitively but they do now close many and their donors do not return.

# %% [markdown]
# New Potential Sources for UVA

# %% [markdown]
# While I do believe that UVA could focus on strengthening their relationship with current donors and attempting to receive return donations, UVA can also consider reaching out to countries that support the other “public ivies”.  For my peer institution comparisons I choose to compare UVA to other “public ivies” such as UT Austin, UNC, UCLA, and William and Mary. Based on the histogram I created that compared these five institutions I found that some of these institutions received large gifts from countries that do not donate to the University of Virginia. On the histogram there is a large tail from Japan to the UCAL, however, Japan does not donate any money to UVA. Although a small tail exists from England to UVA, England has an even larger tail towards UCLA. UVA should consider creating a relationship with Japan and using its similarities to UCLA as a motivator. UVA is similar to all the other public ivies in their size, sports, academics, and much more and should use this to their advantage to try to get countries that donate to other public ivies to also donate to them.

# %% [markdown]
# Conclusion

# %% [markdown]
# UVA has good prospects but is bounded. UVA has an existing donor base of 58 donors so UVA is looking to expand rather than to start fresh. UVA’s average gift size beats that of UNC and UCLA indicating that UVA can close large gifts when given the opportunity. UVA needs to seek out opportunities with large donors such as Japan who donated large quantities to UCLA who is similar to UVA and strengthen the relationship with  England who already gives UVA some money but the potential for more money is there.
